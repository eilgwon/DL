# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets

# %%
a = tf.add(3, 5)
with tf.Session() as sess:
    print(sess.run(a))
# Out:
# 8

# %%
# sess = tf.Session()
# print(sess.run(a))
# sess.close()
# Out:
# 8

# %%
x = 2
y = 3
op1 = tf.add(x, y)
op2 = tf.multiply(x, y)
op3 = tf.pow(op2, op1)

# %%
with tf.Session() as sess:
    op3 = sess.run(op3)
    print(op3)
# Out:
# 7776

# %%
x_data = datasets.load_boston().data[:, 12]
y_data = datasets.load_boston().target
df = pd.DataFrame([x_data, y_data]).transpose()
df.head()

# %%
w = tf.Variable(tf.random_normal([1]))
b = tf.Variable(tf.random_normal([1]))

y_predicted = w * x_data + b

# %%
# loss = tf.reduce_mean(tf.square(y_predicted - y_data))
# optimizer = tf.train.GradientDescentOptimizer(0.001) # Learning Rate
# train = optimizer.minimize(loss)

# %%
_x_data = tf.reshape(x_data, [len(x_data), 1])
_y_data = tf.reshape(y_data, [len(y_data), 1])

W1 = tf.Variable(tf.random_normal([1, 5], dtype=tf.float64))
W2 = tf.Variable(tf.random_normal([5, 10], dtype=tf.float64))
W_out = tf.Variable(tf.random_normal([10, 1], dtype=tf.float64))

hidden1 = tf.nn.elu(tf.matmul(_x_data, W1))
hidden2 = tf.nn.elu(tf.matmul(hidden1, W2))
output = tf.matmul(hidden2, W_out)

# %%
loss = tf.losses.mean_squared_error(output, _y_data)
optimizer = tf.train.AdamOptimizer(0.001) ## Learning Rate
train = optimizer.minimize(loss)

# %%
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    
    for step in range(50000):
        sess.run(train)
        if step % 5000 == 0:
            print('Step {} || loss : {}'.format(step, sess.run(loss)))
        
    output = sess.run(output)
# Out:
# Step 0 || loss : 278.81170654296875
# Step 5000 || loss : 27.443525314331055
# Step 10000 || loss : 27.324644088745117
# Step 15000 || loss : 27.144847869873047
# Step 20000 || loss : 26.71819305419922
# Step 25000 || loss : 26.51762580871582
# Step 30000 || loss : 26.44571876525879
# Step 35000 || loss : 26.4058780670166
# Step 40000 || loss : 26.380367279052734
# Step 45000 || loss : 26.362449645996094

# %%
plt.figure(figsize = (10, 10))
plt.plot(x_data, y_data, 'bo', label='Real Data')
# plt.plot(x_data, x_data * w_out + b_out, 'ro', label='Prediction')
plt.plot(x_data, output, 'ro', label='Prediction')
plt.legend()
plt.show()
